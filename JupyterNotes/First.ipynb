# %%
# %matplotlib inline
from matplotlib import pyplot as plt
plt.plot(range(5))
plt.show()

# %%
# %matplotlib inline
'''
==========================
Dark background style sheet
===========================

This example demonstrates the "dark_background" style, which uses white for
elements that are typically black (text, borders, etc). Note that not all plot
elements default to colors defE!ined by an rc parameter.
!
'''
import numpy as np
import matplotlib.pyplot as plt


plt.style.use('dark_background')

fig, ax = plt.subplots()

L = 6
x = np.linspace(0, L)
ncolors = len(plt.rcParams['axes.prop_cycle'])
shift = np.linspace(0, L, ncolors, endpoint=False)
for s in shift:
    ax.plot(x, np.sin(x + s), 'o-')
ax.set_xlabel('x-axis')
ax.set_ylabel('y-axis')
ax.set_title("'dark_background' style sheet")

plt.show()

# %%
from sympy import *
init_printing()
x=Symbol('x')
expr=x**2-x*8
(expr)
# Out:
#  2
# x  - 8⋅x

# %%
ex=(1-x**2)*(1+x)**2-(x-1+x**2)**2
solve(ex,x)
#ex
# Out:
# ⎡                          __________
# ⎢     2   ⎛  1   √3⋅ⅈ⎞    ╱ √78   29                  11                  2
# ⎢0, - ─ + ⎜- ─ - ────⎟⋅3 ╱  ─── + ──  + ──────────────────────────────, - ─ +
# ⎢     3   ⎝  2    2  ⎠ ╲╱    36   54                        __________    3
# ⎢                                          ⎛  1   √3⋅ⅈ⎞    ╱ √78   29
# ⎢                                       18⋅⎜- ─ - ────⎟⋅3 ╱  ─── + ──
# ⎣                                          ⎝  2    2  ⎠ ╲╱    36   54
#
#                                                   __________
#               11                 ⎛  1   √3⋅ⅈ⎞    ╱ √78   29     2           11
# ────────────────────────────── + ⎜- ─ + ────⎟⋅3 ╱  ─── + ── , - ─ + ──────────
#                     __________   ⎝  2    2  ⎠ ╲╱    36   54     3          ___
#    ⎛  1   √3⋅ⅈ⎞    ╱ √78   29                                             ╱ √7
# 18⋅⎜- ─ + ────⎟⋅3 ╱  ─── + ──                                       18⋅3 ╱  ──
#    ⎝  2    2  ⎠ ╲╱    36   54                                          ╲╱    3
#
#               __________⎤
#              ╱ √78   29 ⎥
# ─────── + 3 ╱  ─── + ── ⎥
# _______   ╲╱    36   54 ⎥
# 8   29                  ⎥
# ─ + ──                  ⎥
# 6   54                  ⎦

# %%
Integral(sqrt(x),x)
# Out:
# ⌠
# ⎮ √x dx
# ⌡

# %%
integrate(sqrt(x),x)
# Out:
#    3/2
# 2⋅x
# ──────
#   3

# %%
# %matplotlib inline
from matplotlib import pyplot as plt
import numpy as np
a=np.arange(-4*np.pi,5*np.pi,np.pi/25)
plt.plot(a,(np.sin(a)/a)**2,'r-')
plt.show()
